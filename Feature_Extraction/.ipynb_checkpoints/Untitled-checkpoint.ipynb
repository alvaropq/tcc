# %%
import pandas as pd

# %%
df = pd.read_csv('cRNA/Base_de_dados.csv')

# %%
df2 = pd.read_csv('lncRNA/Base_de_dados.csv')

# %%
df3 = pd.concat([df,df2],ignore_index=True)

# %%
df3
# Out:
#            AB.1       AD.1    ASSD.1  MAXD.1  MIND.1       AS.1     APL.1  \
# 0     46.095238  17.587302  0.286989    32.0     2.0   7.579494  2.486943
# 1     46.015625  25.093750  0.483234    64.0     2.0  13.403263  2.460813
# 2     44.343750  38.875000  0.579152   134.0     2.0  23.277202  2.407738
# 3     44.734375  43.843750  0.345718    88.0     2.0  21.332354  2.420139
# 4     47.343750  21.218750  0.514749    68.0     2.0  12.834851  2.502976
# ...         ...        ...       ...     ...     ...        ...       ...
# 6990  42.828125  62.281250  0.520607   180.0     6.0  31.942560  2.359623
# 6991  45.435484  20.516129  0.391404    60.0     2.0  10.123021  2.489688
# 6992  49.311475  13.311475  0.429430    44.0     2.0   9.029171  2.643716
# 6993  45.730159  23.301587  0.354854    62.0     2.0  12.992837  2.475166
# 6994  45.112903  23.451613  0.409578    56.0     2.0  12.015685  2.479112
#
#         TALU.1      TU.1    NE.1  ...        k4        k5         k6  \
# ...

# %%
df3.to_csv('Base_de_dados.csv',index=False, header=True)
